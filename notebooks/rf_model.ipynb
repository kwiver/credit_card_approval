# %%
# import lib
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import (
    classification_report, confusion_matrix,
    roc_auc_score, average_precision_score,
    matthews_corrcoef, f1_score,
    recall_score, precision_score, make_scorer
)
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %%
def load_and_explore_dataset(filepath):
    print("=" * 60)
    print("LOAD AND  EXPLORE DATASET")
    print("=" * 60)

    df = pd.read_csv(filepath)

    print("Shape of the dataset")
    print(df.shape)
    print("\nCheck for missing values")
    print(df.isnull().sum())
    print("\nFirst five rows:")
    print(df.head())
    print("\nDescriptive stats")
    print(df.describe())
    print("\nDataset Info")
    print(df.info())
    print("\nStatus Distribution:")
    print(df["status"].value_counts())
    print("\nStatus percentage Distribution:")
    print(df["status"].value_counts(normalize=True) * 100)

    return df

# %%
def identify_features(df):
    print("=" * 60)
    print("IDENTIFY FEATURE DATASET")
    print("=" * 60)

    numerical_features = [
        "total_income",
        "applicant_age",
        "years_of_working",
        "total_bad_debt",
        "total_good_debt"
    ]

    categorical_features = [
        "applicant_gender",
        "education_type",
        "family_status",
        "income_type",
        "job_title"
    ]

    target_column = "status"

    X = df[numerical_features + categorical_features]
    y = df[target_column]

    feature_columns = numerical_features + categorical_features
    
    print("Features Shape:", X.shape)
    print("Target Shape:", y.shape)

    return X, y, numerical_features, categorical_features, feature_columns

# %%
def split_data(X, y, test_size=0.2, random_state=42):
    print("\n" + "=" * 60)
    print("SPLITING DATA")
    print("=" * 60)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )

    print("\nTraining set size", X_train.shape[0])
    print("Testing set size", X_test.shape[0])
    print("\nTraining set price range {:.2f} - {:.2f}".format(
        float(y_train.min()), float(y_train.max())
    ))
    print("\nTesting set price range {:.2f} - {:.2f}".format(
        float(y_test.min()), float(y_test.max())
    ))

    return X_train, X_test, y_train, y_test

# %%
# def build_and_train_model(X_train, y_train, numerical_features, categorical_features, feature_columns):

#     skewed_num_cols = ['total_income', 'total_bad_debt', 'total_good_debt']
    
#     normal_num_cols = ['applicant_age', 'years_of_working']
    
#     categorical_cols = ['applicant_gender', 'income_type', 'education_type',
#                         'family_status', 'job_title']
    
#     # Skewed numericals: median is safer than mean
#     skewed_transformer = Pipeline(steps=[
#         ('imputer', SimpleImputer(strategy='median')),
#         ('scaler', StandardScaler())
#     ])
    
#     # Normal numericals: mean is acceptable
#     normal_transformer = Pipeline(steps=[
#         ('imputer', SimpleImputer(strategy='mean')),
#         ('scaler', StandardScaler())
#     ])
    
#     # Categoricals: constant is safer than most_frequent
#     categorical_transformer = Pipeline(steps=[
#         ('imputer', SimpleImputer(strategy='constant', fill_value='Unknown')),
#         ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
#     ])
    
    
#     # --- Combine ---
#     preprocessor = ColumnTransformer(transformers=[
#         ('skewed_num', skewed_transformer, skewed_num_cols),
#         ('normal_num', normal_transformer, normal_num_cols),
#         ('cat', categorical_transformer, categorical_cols)
#     ])

#     model = Pipeline(steps=[
#         ("preprocessor", preprocessor),
#         ("classifier", RandomForestClassifier(
#             # n_estimators=200,
#             # max_depth=6,
#             # min_samples_split=5,
#             # min_samples_leaf=2,
#             class_weight="balanced",
#             random_state=42
#         ))
#     ])

#     # parameter grid
#     param_grid = {
#         "classifier__n_estimators": [200, 500, 700],
#         "classifier__max_depth": [4, 6, 8],
#         "classifier__min_samples_split": [5, 10, 20],
#         "classifier__min_samples_leaf": [2, 5, 10]
#         # "randomforestregressor__max_features": ["sqrt", "log2"]
#     }
    
#     negative_f1 = make_scorer(f1_score, pos_label=0)

#     # grid search
#     grid_search = GridSearchCV(
#         model,
#         param_grid,
#         cv=5,
#         scoring=negative_f1,  
#         n_jobs=-1,
#         verbose=1
#     )
#     grid_search.fit(X_train, y_train)

#     print("\nBest Parameters Found:")
#     print(grid_search.best_params_)

#     print("\nBest Cross-Validation R2 Score:")
#     print(grid_search.best_score_)

#     return grid_search.best_estimator_

# %%
def build_and_train_model(X_train, y_train, numerical_features, categorical_features, feature_columns):
    print("\n" + "=" * 60)
    print("BUILDING & TRAINING PIPELINE")
    print("=" * 60)

    skewed_num_cols = ['total_income', 'total_bad_debt', 'total_good_debt']
    
    normal_num_cols = ['applicant_age', 'years_of_working']
    
    categorical_cols = ['applicant_gender', 'income_type', 'education_type',
                        'family_status', 'job_title']
    
    # Skewed numericals: median is safer than mean
    skewed_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])
    
    # Normal numericals: mean is acceptable
    normal_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])
    
    # Categoricals: constant is safer than most_frequent
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='Unknown')),
        ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
    ])
    
    
    # --- Combine ---
    preprocessor = ColumnTransformer(transformers=[
        ('skewed_num', skewed_transformer, skewed_num_cols),
        ('normal_num', normal_transformer, normal_num_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

    model = Pipeline(steps=[
        ("preprocessor", preprocessor),
        ("classifier", RandomForestClassifier(
            n_estimators=200,
            max_depth=8,
            min_samples_split=5,
            min_samples_leaf=2,
            class_weight="balanced",
            random_state=42
        ))
    ])

    model.fit(X_train, y_train)
    print("Model trained successfully")

    print("\nrf_model coefficients")
    feature_names = model.named_steps["preprocessor"].get_feature_names_out()
    importances = model.named_steps["classifier"].feature_importances_

    rf_importance = pd.DataFrame({
        "Feature": feature_names,
        "Importance": importances
    })
    rf_importance = rf_importance.sort_values(
        by="Importance",
        ascending=False
    )
    
    print(rf_importance.head(10))
    return model

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test):
    print("\n" + "=" * 60)
    print("MODEL EVALUATION")
    print("=" * 60)

    y_train_pred  = model.predict(X_train)
    y_test_pred   = model.predict(X_test)
    
    y_train_proba = model.predict_proba(X_train)[:, 1]
    y_test_proba  = model.predict_proba(X_test)[:, 1]

    metrics = {
        "pr_auc":  (average_precision_score(y_train, y_train_proba),
                    average_precision_score(y_test,  y_test_proba)),
        "recall":  (recall_score(y_train, y_train_pred),
                    recall_score(y_test,  y_test_pred)),
        "f1":      (f1_score(y_train, y_train_pred),
                    f1_score(y_test,  y_test_pred)),
    }

    print(f"\n{'Metric':<12} {'Train':>10} {'Test':>10}")
    print("-" * 34)
    for name, (train_val, test_val) in metrics.items():
        print(f"{name.upper():<12} {train_val:>10.4f} {test_val:>10.4f}")

    # test classification report
    print("\n" + "=" * 60)
    print("CLASSIFICATION REPORT — TEST")
    print("=" * 60)
    print(classification_report(y_test, y_test_pred, target_names=["Negative", "Positive"]))

    # confusion metrics
    tn, fp, fn, tp = confusion_matrix(y_test, y_test_pred).ravel()
    print(f"  TP: {tp}  |  FP: {fp}")
    print(f"  FN: {fn}  |  TN: {tn}")

    # Stratified CV on PR-AUC only
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    cv_pr_auc = cross_val_score(model, X_train, y_train, cv=cv, scoring="average_precision")
    print(f"\n  CV PR-AUC:  {cv_pr_auc.mean():.4f} ± {cv_pr_auc.std():.4f}")

    return {
        "pr_auc_train":  metrics["pr_auc"][0],
        "pr_auc_test":   metrics["pr_auc"][1],
        "recall_train":  metrics["recall"][0],
        "recall_test":   metrics["recall"][1],
        "f1_train":      metrics["f1"][0],
        "f1_test":       metrics["f1"][1],
        "cv_pr_auc":     cv_pr_auc,
        "y_test_pred":   y_test_pred,
        "y_test_proba":  y_test_proba,
    }

# %%
def save_model_artifact(model):
    print("\n" + "=" * 60)
    print("SAVING MODEL ARTIFACT")
    print("=" * 60)

    joblib.dump(model, "../models/rf_model_pipeline.pkl")
    print("Pipeline model saved successfully")

    print("\n" + "=" * 60)
    print("ALL MODEL ARTIFACT SAVED SUCCESSFULLY")
    print("=" * 60)

# %%
def main():
    filepath = "../data/cleaned/cleaned_credit_card_approval.csv"

    df = load_and_explore_dataset(filepath)

    X, y, numerical_features, categorical_features, feature_columns = identify_features(df)

    X_train, X_test, y_train, y_test = split_data(X, y)

    model = build_and_train_model(X_train, y_train, numerical_features, categorical_features, feature_columns)

    evaluate_model(model, X_train, X_test, y_train, y_test)

    save_model_artifact(model)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# LOAD AND  EXPLORE DATASET
# ============================================================
# Shape of the dataset
# (10454, 11)
#
# Check for missing values
# applicant_gender    4096
# total_income           0
# income_type         4225
# education_type      4213
# family_status       4178
# job_title           4239
# applicant_age       4181
# years_of_working    4191
# total_bad_debt      4181
# total_good_debt     4258
# status                 0
# dtype: int64
#
# First five rows:
#   applicant_gender  total_income    income_type  \
# 0             Male        180000        Working
# 1              NaN        112500            NaN
# 2           Female        270000  State Servant
# 3           Female        135000            NaN
# 4              NaN         94500  State Servant
#
#                   education_type family_status   job_title  applicant_age  \
# 0  Secondary / Secondary Special       Married    Managers           45.0
# 1                            NaN           NaN         NaN            NaN
# 2               Higher Education       Married         NaN            NaN
# 3                            NaN           NaN  Core Staff            NaN
# 4               Higher Education           NaN         NaN           51.0
#
#    years_of_working  total_bad_debt  total_good_debt  status
# 0               NaN             NaN             28.0       1
# 1               NaN             0.0              NaN       1
# 2               NaN             0.0             27.0       1
# 3               6.0             9.0             40.0       1
# 4               6.0             0.0             46.0       1
#
# Descriptive stats
#         total_income  applicant_age  years_of_working  total_bad_debt  \
# count   10454.000000    6273.000000       6263.000000     6273.000000
# mean   193344.411230      40.918859          7.715791        0.353898
# std     94621.767306       9.582713          6.500597        1.569517
# min     27000.000000      22.000000          1.000000        0.000000
# 25%    135000.000000      33.000000          3.000000        0.000000
# 50%    180000.000000      40.000000          6.000000        0.000000
# 75%    225000.000000      48.000000         10.000000        0.000000
# max    787500.000000      68.000000         44.000000       40.000000
#
#        total_good_debt        status
# count      6196.000000  10454.000000
# mean         21.401388      0.996269
# std          14.878278      0.060968
# min           1.000000      0.000000
# 25%           9.000000      1.000000
# 50%          18.000000      1.000000
# 75%          31.000000      1.000000
# max          61.000000      1.000000
#
# Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10454 entries, 0 to 10453
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   applicant_gender  6358 non-null   object
#  1   total_income      10454 non-null  int64
#  2   income_type       6229 non-null   object
#  3   education_type    6241 non-null   object
#  4   family_status     6276 non-null   object
#  5   job_title         6215 non-null   object
#  6   applicant_age     6273 non-null   float64
#  7   years_of_working  6263 non-null   float64
#  8   total_bad_debt    6273 non-null   float64
#  9   total_good_debt   6196 non-null   float64
#  10  status            10454 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 898.5+ KB
# None
#
# Status Distribution:
# status
# 1    10415
# 0       39
# Name: count, dtype: int64
#
# Status percentage Distribution:
# status
# 1    99.626937
# 0     0.373063
# Name: proportion, dtype: float64
# ============================================================
# IDENTIFY FEATURE DATASET
# ============================================================
# Features Shape: (10454, 10)
# Target Shape: (10454,)
#
# ============================================================
# SPLITING DATA
# ============================================================
#
# Training set size 8363
# Testing set size 2091
#
# Training set price range 0.00 - 1.00
#
# Testing set price range 0.00 - 1.00
#
# ============================================================
# BUILDING & TRAINING PIPELINE
# ============================================================
# Model trained successfully
#
# rf_model coefficients
#                         Feature  Importance
# 1    skewed_num__total_bad_debt    0.239971
# 2   skewed_num__total_good_debt    0.195186
# 0      skewed_num__total_income    0.114514
# 3     normal_num__applicant_age    0.095292
# 8            cat__family_status    0.068870
# 4  normal_num__years_of_working    0.067855
# 9                cat__job_title    0.064814
# 5         cat__applicant_gender    0.064783
# 7           cat__education_type    0.049518
# 6              cat__income_type    0.039198
#
# ============================================================
# MODEL EVALUATION
# ============================================================
#
# Metric            Train       Test
# ----------------------------------
# PR_AUC           1.0000     0.9987
# RECALL           0.9998     1.0000
# F1               0.9999     0.9990
#
# ============================================================
# CLASSIFICATION REPORT — TEST
# ============================================================
#               precision    recall  f1-score   support
#
#     Negative       1.00      0.43      0.60         7
#     Positive       1.00      1.00      1.00      2084
#
#     accuracy                           1.00      2091
#    macro avg       1.00      0.71      0.80      2091
# weighted avg       1.00      1.00      1.00      2091
#
#   TP: 2084  |  FP: 4
#   FN: 0  |  TN: 3
#
#   CV PR-AUC:  0.9990 ± 0.0005
#
# ============================================================
# SAVING MODEL ARTIFACT
# ============================================================
# Pipeline model saved successfully
#
# ============================================================
# ALL MODEL ARTIFACT SAVED SUCCESSFULLY
# ============================================================
